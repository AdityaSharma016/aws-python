# %% [markdown]
# Collecting data
#        |
#   Clean Data
#        |
# Handle Missing vlalues
#        |
#     Encoding
#        |
# Feature Scaling
#        |
# Train-Test Split
#        |
#   Train Model
#        |
#  Evaluate Model
#        |
#   Improve Model

# %% [markdown]
# print("hello my name is aditya")

# %%
print("helolo my name is aditya")
# Out:
# helolo my name is aditya
