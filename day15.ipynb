# %% [markdown]
# Collecting data
#        |
#   Clean Data
#        |
# Handle Missing vlalues
#        |
#     Encoding
#        |
# Feature Scaling
#        |
# Train-Test Split
#        |
#   Train Model
#        |
#  Evaluate Model
#        |
#   Improve Model
