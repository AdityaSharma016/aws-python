# %% [markdown]
# **LIST methods**
# append

# %%
l = [ 10 ,20 ,30]
l.append(40)# append() method adds an element at the end of the list
l.insert(1,60)# insert() method inserts an element to the list at the specified index
print(l)
# Out:
# [10, 60, 20, 30, 40]

# %%
a = [ 10 ,20 ,30]
print(len(a))# len() function returns the number of items in a list
a[0] # indexing starts from 0
# Out:
# 3
# 10

# %% [markdown]
# **LOOP**
# 1. for- for i in range (s):
#         for i in[10,20,30]
#            body
# 2. while- while i<n:
#      print(i)
#      i=+1

# %%
#for loop 
for i in a:
    print(i)
# Out:
# 10
# 20
# 30

# %%
for i in range(3):
    print (i)
# Out:
# 0
# 1
# 2

# %%
l = [ 10 ,20 ,30]
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30
