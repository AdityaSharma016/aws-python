# %% [markdown]
# file system
# file handling

# %%
f = open("hello.txt.txt", "r")
f.read()
f.close()

# %%
f = open("hello.txt.txt","a")
f.write("my name is aditya and ")
f.close()

# %%
f=open("hello.txt.txt","r")
f.read()
# Out:
# 'i am from jaipurmy name is adityamy name is aditya and '

# %%
import numpy as np

# %%
l = [10,20,30,40]
l*2
# Out:
# [10, 20, 30, 40, 10, 20, 30, 40]

# %%
arr = np.array(l)
arr
# Out:
# array([10, 20, 30, 40])
