# %%
import numpy as np
import pandas as pd 
data ={
    "experience":[1,2,3,4,5],
    "salary":[100,200,300,400,500]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    experience  salary
# 0           1     100
# 1           2     200
# 2           3     300
# 3           4     400
# 4           5     500

# %%
#hande missing values in pandas
