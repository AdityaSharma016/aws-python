# %%
class Student :
    def __init__ (self, name , age , roll_no): 
        self.name =name 
        self.age = age
        self.roll_no = roll_no
s = Student("John", 20, 101)
print(s.name)
# Out:
# John

# %%
class Student:
  def __init__(this,name,roll_no,age):
    this.name = name
    this.roll_no = roll_no
    this.age = age
 
# s = Student("nikhil",123,20)
# print(s.name,s.roll_no,s.age)
 
s = Student(roll_no=123,name='nikhil',age=20)
print(s.name,s.roll_no,s.age)
# Out:
# nikhil 123 20

# %%
class Student :
    def __init__(this, name, age , roll_no=None): 
        this.name =name 
        this.age = age
        this.roll_no = roll_no
s = Student("aditya", 16)
print(s.name,s.age,s.roll_no)
# Out:
# aditya 16 None
