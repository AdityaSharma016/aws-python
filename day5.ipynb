# %% [markdown]
# wap to run the while looop continue inside that loop tke a input any number from an user unitll user give input to number 10.

# %%
while(True):
    n = int(input("Enter a number: "))
    if n == 10:
        print("10 is found")
        break
# Out:
# 10 is found

# %% [markdown]
# there is a dictonary and users are there with the aryanss with the name of students pruint the names by the while noop help

# %%
d = {"Users":{"aryains":["aditya","aryan","amit","ayush"]}}
i = 0
while i < len(d["Users"]["aryains"]):
      print(d["Users"]["aryains"][i])
      i += 1
# Out:
# aditya
# aryan
# amit
# ayush
